# %% [markdown]
# | Aufgabentyp / Suchbegriff in Moodle  | Deine Datei in VS Code                      | Bemerkung & Stichworte                                                     |
# |--------------------------------------|---------------------------------------------|----------------------------------------------------------------------------|
# | Zahlensysteme & IEEE 754             | 01_Zahlendarstellungen_IEEE754.ipynb        | Binär, Oktal, Hex, Zweierkomplement, Vorzeichen, Mantisse, Exponent.       |
# | Mastertheorem (Komplexität)          | 19_MastertheoremKomplexität.ipynb (oder 02) | O(n) bestimmen. Einfach Parameter d und b eintragen.                       |
# | Rekursionen auflösen                 | 13_RekursionAufloesen.ipynb                 | Aus Rekursion eine direkte/explizite Formel machen (rsolve).               |
# | Induktion: Beweise & Terme           | 20_Algebrainspektor_Induktion.ipynb         | Setzt n+1 ein, multipliziert aus und vereinfacht die Differenz auf 0.      |
# | Grenzwerte (Limes) & L'Hôpital       | 04_Grenzwerte_LHospital.ipynb               | Prüft automatisch Zähler/Nenner und leitet bei 0/0 ab.                     |
# | Stetigkeit prüfen                    | 21_Stetigkeitspruefer_LiRe.ipynb            | Linksseitiger vs. rechtsseitiger Grenzwert (Limes von + und -).            |
# | Komplexe Ableitungen (Kettenregel)   | 12_Komplexe_Ableitungen_Kettenregel.ipynb   | Verschachtelte Funktionen, Produktregel, mehrfache Ableitungen.            |
# | Kurvendiskussion                     | 05_Kurvendiskussion_Extrema.ipynb           | Ableitungen, Nullstellen, Hoch-/Tiefpunkte (mit Begründung durch f'').     |
# | Extremwertaufgaben (Textaufgabe)     | 14_Extremwertaufgaben_Opt_Flaeche...        | Optimierung (z.B. max. Rechteck). Du baust die Zielfunktion, Code rechnet. |
# | Taylor-Polynome                      | 06_Taylor_Polynome.ipynb                    | Summanden berechnen.                                                       |
# | Fläche zwischen 2 Kurven             | 07_Integrale_Schnittpunkte_Flaechen.ipynb   | Findet automatisch die Schnittpunkte und nutzt sie als Integralgrenzen.    |
# | Fläche mit der x-Achse               | 15_FlaecheFunktionUndXAchse_Teil...         | Teilt das Integral an den Nullstellen auf und addiert die Beträge!         |
# | Stammfunktion & Anfangswert          | 18_StammfunktionAnfangswertRot... (oder 08) | Unbestimmtes Integral, berechnet C durch Einsetzen von z.B. F(1) = 2.      |
# | Rotationskörper                      | 18_StammfunktionAnfangswertRot... (oder 08) | Berechnet das exakte Volumen bei Rotation um die x-Achse.                  |
# | Numerische Integration               | 22_NumerischeIntegration.ipynb              | Wenn es keine exakte Stammfunktion gibt (SciPy Approximation).             |
# | Newton-Verfahren                     | 09_Newton_Verfahren.ipynb                   | Nullstellen iterativ annähern.                                             |
# | Cubic Splines                        | 10_Cubic_Splines.ipynb                      | Stützpunkte glatt verbinden.                                               |
# | Reihenkonvergenz (Integralkriterium) | 16_Reihenkonvergenz_beweisen_Int...         | Integriert von 1 bis Unendlich für den Konvergenz-Beweis.                  |
# | Landau-Symbole Theorie               | 17_LandauSymbole.ipynb                      | Dein Spickzettel-Code für die O-Klassen.                                   |
